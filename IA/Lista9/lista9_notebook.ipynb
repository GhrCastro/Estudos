# %% [markdown]
# 1. CÓDIGO BASE EM PYTHON
#
# A ideia é você aproveitar a estrutura do notebook da Laura (títulos, seções) e encaixar esse código (adaptando onde precisar).
#
# 1.1. Imports e carregamento dos dados

# %%
# ===== IMPORTS BÁSICOS =====
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from scipy import stats

# Pré-processamento
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

# Balanceamento
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import TomekLinks

# Modelo de classificação (para comparar antes/depois)
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report

# Agrupamento (Questão 2)
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_score

# SOM (precisa instalar antes:  pip install minisom)
from minisom import MiniSom

# Configs gerais
pd.set_option("display.max_columns", None)
plt.rcParams["figure.figsize"] = (8, 4)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 13
#      10 from sklearn.model_selection import train_test_split
#      12 # Balanceamento
# ---> 13 from imblearn.over_sampling import SMOTE
#      14 from imblearn.under_sampling import TomekLinks
#      16 # Modelo de classificação (para comparar antes/depois)
#
# ModuleNotFoundError: No module named 'imblearn'

# %% [markdown]
# 1.2. Visualização da base (EDA, histogramas, boxplots)

# %%
# Informações gerais
df.info()
df.describe()

# %% [markdown]
# Distribuição da variável alvo (Class)

# %%
# Distribuição da classe
class_counts = df["Class"].value_counts()
print(class_counts)

class_counts.plot(kind="bar")
plt.title("Distribuição da Classe (0 = Normal, 1 = Fraude)")
plt.xlabel("Classe")
plt.ylabel("Frequência")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Distribuição da classe
# ----> 2 class_counts = df["Class"].value_counts()
#       3 print(class_counts)
#       5 class_counts.plot(kind="bar")
#
# NameError: name 'df' is not defined

# %% [markdown]
# Histogramas de algumas variáveis

# %%
# Histograma do Amount
plt.hist(df["Amount"], bins=50, edgecolor="black")
plt.title("Histograma - Amount")
plt.xlabel("Amount")
plt.ylabel("Frequência")
plt.show()

# Histograma do Time
plt.hist(df["Time"], bins=50, edgecolor="black")
plt.title("Histograma - Time")
plt.xlabel("Time")
plt.ylabel("Frequência")
plt.show()

# %%
# Histograma para algumas V's (exemplo V1 a V6 pra não ficar gigante)
cols_v = [f"V{i}" for i in range(1, 7)]

for col in cols_v:
    plt.hist(df[col], bins=50, edgecolor="black")
    plt.title(f"Histograma - {col}")
    plt.xlabel(col)
    plt.ylabel("Frequência")
    plt.show()

# %% [markdown]
# Boxplots (para ver outliers)

# %%
# Boxplot de Amount
plt.boxplot(df["Amount"], vert=False)
plt.title("Boxplot - Amount")
plt.xlabel("Amount")
plt.show()

# Boxplot de Time
plt.boxplot(df["Time"], vert=False)
plt.title("Boxplot - Time")
plt.xlabel("Time")
plt.show()
